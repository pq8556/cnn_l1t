# %% [markdown]
# ### CSC stations hit map image
#
#
# * I plotted hit maps for 4 bins for pt
#     * bins (also separately for +ve and -ve)
#         * 2- 10 (GeV)
#         * 10 - 30
#         * 30 - 100
#         * 100 - 1000
#     * hits only count once; meaning this is not histogram.
#         * I tried histogram. I centered hit on station 2 and plotted differences. As a result the center value has too many counts. other points relatively less counts; So it's hard to see other points. Working on fixing this issue.

# %%
import sys
sys.path.append('./custom_modules/') 
import module1 as md
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# !cat configs/filepath.txt
X, y = md.load_input_file("/uscms_data/d3/mkim/MKWorkingArea/CMSSW_10_2_0/src/JL/Melrose/P2_CMSSW_10_1_5/src/L1TMuonSimulations/Analyzers/test7/histos_tba.20.npz")
# Out:
# fnal cmslpc computer cluster
#
# /uscms_data/d3/mkim/MKWorkingArea/CMSSW_10_2_0/src/JL/Melrose/P2_CMSSW_10_1_5/src/L1TMuonSimulations/Analyzers/test7/histos_tba.20.npz
# <class 'numpy.lib.npyio.NpzFile'>
# ['variables', 'parameters']

# %%
# +ve
t1 = y < 1./100. # pt lower +ve
t2 = y > 1./1000 # pt higher +ve
t3 = np.logical_and(t1,t2)
del t1, t2

# %%
# -ve
t1 = y > -1./100 # pt lower -ve
t2 = y < -1./1000 # pt higher -ve
t3 = np.logical_and(t1,t2)
del t1, t2

# %%
rpx, cpx = 2000, 200
img1 = np.full((rpx,cpx),0)
def coor_to_img(X,i):
    for x in X[i]:
        #print(x[0]-X[0,1,0]+rpx/2,x[1]-X[0,1,1]+cpx/2)
        #print(x-X[0,1])
        # img1[x[0]-X[i,1,0]+rpx/2,x[1]-X[i,1,1]+cpx/2] = 1 # phi, theta centered
        img1[x[0]-X[i,1,0]+rpx/2,x[1]] = 1
    return None

X_rst = X[t3]
for i in range(len(X_rst)):
    coor_to_img(X_rst,i)

# %%
# 2-10 +ve
plt.figure(figsize=(100,500))
plt.imshow(np.transpose(img1), cmap="Greys")
plt.axvline(x=rpx/2)

# %%
# 2-10 -ve
plt.figure(figsize=(100,500))
plt.imshow(np.transpose(img1), cmap="Greys")
plt.axvline(x=rpx/2)

# %%
# 10-30 +ve
plt.figure(figsize=(100,500))
plt.imshow(np.transpose(img1), cmap="Greys")
plt.axvline(x=rpx/2)

# %%
# 10-30 -ve
plt.figure(figsize=(100,500))
plt.imshow(np.transpose(img1), cmap="Greys")
plt.axvline(x=rpx/2)

# %%
# 30-100 +ve
plt.figure(figsize=(100,500))
plt.imshow(np.transpose(img1), cmap="Greys")
plt.axvline(x=rpx/2)

# %%
# 30-100 -ve
plt.figure(figsize=(100,500))
plt.imshow(np.transpose(img1), cmap="Greys")
plt.axvline(x=rpx/2)

# %%
# 100-1000 +ve
plt.figure(figsize=(100,500))
plt.imshow(np.transpose(img1), cmap="Greys")
plt.axvline(x=rpx/2)

# %%
# 100-1000 -ve
plt.figure(figsize=(100,500))
plt.imshow(np.transpose(img1), cmap="Greys")
plt.axvline(x=rpx/2)
